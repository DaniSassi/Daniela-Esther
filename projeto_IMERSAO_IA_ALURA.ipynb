# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniSassi/Daniela-Esther/blob/main/projeto_IMERSAO_IA_ALURA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BLOCO 1: Importações e Configuração da Chave da API
import os
import random
from google.cloud import language_v1

# Sua KEY API do Google IA Studio (lembre-se de substituir pela sua chave real)
os.environ["GOOGLE_API_KEY"] = "GOOGLE_API_KEY_2"

# %%
# BLOCO 2: Biblioteca de Respostas com Imagens, Frases e Emojis
biblioteca_respostas = {
    "segunda-feira": [
        {
            "imagem": "https://images.unsplash.com/photo-1548690312-e3b852c180a3?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",  # Montanhas ao amanhecer
            "frase": "Comece a semana com inspiração! ✨ Compartilhe uma imagem ou uma palavra que te motive hoje. #InspiraBot #SegundaInspiradora",
        },
        {
            "imagem": "https://images.unsplash.com/photo-1503972249348-4116648472ff?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",  # Luz através das árvores
            "frase": "Que a luz desta nova semana ilumine seus caminhos e ideias! 💡 #InspiraBot #NovaSemana",
        },
        {
            "imagem": "https://images.unsplash.com/photo-1516321318423-f06f57725081?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",  # Espiral abstrata
            "frase": "Deixe a inspiração fluir como uma espiral de novas possibilidades! 🌀 #InspiraBot #Criatividade",
        },
    ],
    "sexta-feira": [
        {
            "imagem": "https://images.unsplash.com/photo-1519681393784-d1202a96c94b?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",  # Pôr do sol na praia
            "frase": "Sexta-feira chegou! 🎉 Qual foi a sua pequena vitória desta semana? Compartilhe nos comentários! #InspiraBot #PequenasVitórias",
        },
        {
            "imagem": "https://images.unsplash.com/photo-1504851788829-895d55449c28?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG0dby1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",  # Mãos brindando com luzes desfocadas
            "frase": "Celebrando as pequenas conquistas que nos impulsionam! 🥂 Qual é a sua desta semana? #InspiraBot #VitóriasDaSemana",
        },
        {
            "imagem": "https://images.unsplash.com/photo-1485460327202-b9017929474c?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",  # Confetes caindo
            "frase": "Sextou com alegria e reconhecimento! ✨ Compartilhe uma pequena vitória que te deixou feliz esta semana. 😊 #InspiraBot #Sextou",
        },
    ],
    "positivo": ["Que legal! 😊", "Adorei! 😄", "Ótima vitória! 🎉", "Incrível! ✨", "Concordo plenamente! 👍"],
    "negativo": ["Sinto muito. 😔", "Que pena... 😟", "Não parece bom. 🤔", "Discordo. 😒", "Isso é decepcionante. 😞"],
    "neutro": ["Entendi. 😐", "Hmm, interessante. 🧐", "Ok. 👌", "Pode ser. 🤷", "Anotado. 📝"],
    "humor": ["Hahaha! 😂", "Que engraçado! 😄", "Você é demais! 🤣", "Ri muito! 😂", ":D 😉"],
    "motivação": ["Acredite em você! 💪", "Você consegue! 🔥", "Não desista! 🚀", "Força! 🌟", "Continue assim! 👍", "Parabéns, continue se aprimorando!"],
}

# %%
# BLOCO 3: Função para Simular a Análise de Sentimento
def responder(comentario):
    """Simula a análise de sentimento do comentário e retorna uma resposta apropriada com emojis."""
    print(f"Comentário recebido: {comentario}")
    score = 0.0  # Inicializa o score como neutro

    if "adorei" in comentario.lower() or "incrível" in comentario.lower() or "feliz" in comentario.lower():
        score = 0.8
        print(f"Sentimento simulado: Positivo (score={score:.2f})")
        return random.choice(biblioteca_respostas["positivo"])
    elif "triste" in comentario.lower() or "péssimo" in comentario.lower() or "não gostei" in comentario.lower():
        score = -0.7
        print(f"Sentimento simulado: Negativo (score={score:.2f})")
        return random.choice(biblioteca_respostas["negativo"])
    elif "haha" in comentario.lower() or "kkk" in comentario.lower() or "engraçado" in comentario.lower():
        score = 0.5
        print(f"Sentimento simulado: Humor (score={score:.2f})")
        return random.choice(biblioteca_respostas["humor"])
    elif "motivação" in comentario.lower() or "ânimo" in comentario.lower() or "força" in comentario.lower():
        score = 0.6
        print(f"Sentimento simulado: Motivação (score={score:.2f})")
        return random.choice(biblioteca_respostas["motivação"])
    else:
        score = 0.0
        print(f"Sentimento simulado: Neutro (score={score:.2f})")
        return random.choice(biblioteca_respostas["neutro"])

# %%
# BLOCO 4: Função para Simular a Postagem de Conteúdo Proativo
def postar_conteudo_proativo(dia_da_semana):
    """Simula a postagem de conteúdo proativo com imagem e frase."""
    if dia_da_semana.lower() == "segunda-feira":
        conteudo = random.choice(biblioteca_respostas["segunda-feira"])
        print(f"🚀 Postando na Segunda-feira:\n  Imagem: {conteudo['imagem']}\n  Frase: {conteudo['frase']}")
        # Aqui, em uma implementação real, você postaria a imagem e a frase no Instagram
    elif dia_da_semana.lower() == "sexta-feira":
        conteudo = random.choice(biblioteca_respostas["sexta-feira"])
        print(f"🎉 Postando na Sexta-feira:\n  Imagem: {conteudo['imagem']}\n  Frase: {conteudo['frase']}")
        # Aqui, em uma implementação real, você postaria a imagem e a frase no Instagram
    else:
        print(f"Não há conteúdo proativo agendado para {dia_da_semana}.")

# %%
# BLOCO 5: Simulação de Interação e Postagem Proativa
# Simulação de postagem proativa
postar_conteudo_proativo("Segunda-feira")
print("\n--- Interações ---")
# Exemplos de interação
comentarios_teste = [
    "Que post inspirador! Adorei! 😊",
    "Essa semana foi bem desafiadora... 😔",
    "Hahaha, muito engraçado! 😂",
    "Preciso de um pouco de motivação hoje. 💪",
    "Interessante essa reflexão. 🤔",
    "Consegui finalizar um projeto! 🎉",
    "Não gostei muito... 😒"
]

for comentario in comentarios_teste:
    resposta_ia = responder(comentario)
    print(f"Comentário: {comentario} -> Resposta: {resposta_ia}")

postar_conteudo_proativo("Sexta-feira")
# Out:
# 🚀 Postando na Segunda-feira:
#   Imagem: https://images.unsplash.com/photo-1516321318423-f06f57725081?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D
#   Frase: Deixe a inspiração fluir como uma espiral de novas possibilidades! 🌀 #InspiraBot #Criatividade
#
# --- Interações ---
# Comentário recebido: Que post inspirador! Adorei! 😊
# Sentimento simulado: Positivo (score=0.80)
# Comentário: Que post inspirador! Adorei! 😊 -> Resposta: Ótima vitória! 🎉
# Comentário recebido: Essa semana foi bem desafiadora... 😔
# Sentimento simulado: Neutro (score=0.00)
# Comentário: Essa semana foi bem desafiadora... 😔 -> Resposta: Pode ser. 🤷
# Comentário recebido: Hahaha, muito engraçado! 😂
# Sentimento simulado: Humor (score=0.50)
# Comentário: Hahaha, muito engraçado! 😂 -> Resposta: Hahaha! 😂
# Comentário recebido: Preciso de um pouco de motivação hoje. 💪
# Sentimento simulado: Motivação (score=0.60)
# ...

# %%
# BLOCO 6: Simulação Interativa da Resposta de Sexta-feira

print("\n--- Simulação Interativa da Resposta de Sexta-feira ---")

pergunta_sexta = random.choice(biblioteca_respostas["sexta-feira"])["frase"]
print(f"🤖 InspiraBot (Sexta-feira): {pergunta_sexta}")

resposta_usuario = input("💬 Sua pequena vitória desta semana: ")

if resposta_usuario:
    resposta_bot = responder(resposta_usuario)
    print(f"🤖 InspiraBot responde: {resposta_bot}")
else:
    print("Você não compartilhou sua pequena vitória. 🤔")
# Out:
# --- Simulação Interativa da Resposta de Sexta-feira ---
# 🤖 InspiraBot (Sexta-feira): Sexta-feira chegou! 🎉 Qual foi a sua pequena vitória desta semana? Compartilhe nos comentários! #InspiraBot #PequenasVitórias
# 💬 Sua pequena vitória desta semana: Me sinto motivada, Consegui terminar meu projeto Imersão IA ALURA, a tempo! Feliz!!!!
# Comentário recebido: Me sinto motivada, Consegui terminar meu projeto Imersão IA ALURA, a tempo! Feliz!!!!
# Sentimento simulado: Positivo (score=0.80)
# 🤖 InspiraBot responde: Que legal! 😊
